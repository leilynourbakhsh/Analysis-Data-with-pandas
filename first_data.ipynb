# %%
import pandas as pd
my_data=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
row_data=my_data[['customer name','mobile number','address','final cost']]
paied=row_data.groupby(['customer name'])['final cost'].sum().sort_values()
paied
# Out:
# customer name
# حامد  بدیعی               704000.0
# یعقوب صالحی چرمهینی      1720000.0
# حمید کهنمویی             3576000.0
# محمد شفیعیان             6462000.0
# مهران براتي              7860000.0
# حمیدرضا دهقان            8670000.0
# محمد رضا گنجی           11240000.0
# عباس ویسی               11780399.0
# سالار                   12436000.0
# احمد رضا  خرم           13081796.0
# سیدعبدالله  تقوی        14736000.0
# بهفر خانی               18426000.0
# عباس حیدریان            19650400.0
# فرهاد ثالثی             47780720.0
# محمد بیگی               64855518.0
# عباس بروجی              66337160.0
# حسین  عبدالرضایی        75885037.0
# پویا هدایتی             80282170.0
# اتوسرویس ترافیک         89339103.0
# محسن  سلیمانی          108988792.0
# سید رضا حسینی          147551960.0
# علی آخوندی             193184177.0
# حمیدرضا تبریزیان       290501028.0
# Name: final cost, dtype: float64

# %%
import pandas as pd
df2=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
df2.groupby(['title'])['number'].sum().sort_values(ascending=False)
df=pd.DataFrame(df2.groupby(['title'])['number'].sum().sort_values(ascending=False))
df
#sort products
# Out:
#                                                     number
# title
# روغن موتور SC مدل سوپركيان ويژه (50W) حجم1لیتر ...   144.0
# فيلتر هوا  پژو-پارس-سمند لوکومبیل                    128.0
# روغن موتور SL GIII مدل (10W-40) حجم4لیتر موتوسل      116.0
# روغن موتور SM MAGNATEC مدل (10W-40) حجم4لیتر كا...   115.0
# فیلترهوای پراید انژکتوری بهران                       108.0
# روغن موتور SLجدید (20W-50) حجم4لیتر موتوسل           104.0
# روغن موتور SL مدل ایرانول 16000 (20W-50) حجم4لی...   102.0
# هزینه ارسال - هزينه ارسال                             79.0
# روغن موتور SJ مدل پلاستیکی (10W-40) حجم4لیتر سپ...    72.0
# شیشه شور 3 لیتری  آبیران                              66.0
# فيلتر هوا  پراید انژکتورر توری دار لوکومبیل           64.0
# روغن موتور SE مدل پلاستیکی (20W-50) حجم4لیتر سپ...    60.0
# روغن موتور SC مدل پلاستیکی (40W) حجم4لیتر سپاهان      60.0
# روغن موتور مدل اسپیدی طلایی فلزی (20W-50) حجم1ل...    48.0
# روغن موتور پلاستیکی (50W) حجم1لیتر سپاهان             44.0
# ...

# %%
import pandas as pd
df3=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
df3.groupby(['customer name'])['final cost'].sum().sort_values(ascending=False)
data=pd.DataFrame(df3.groupby(['customer name'])['final cost'].sum().sort_values(ascending=False))
data
df3.groupby(['customer name'])['address']
data1=pd.DataFrame(df3.groupby(['customer name'])['address'],columns=['customer name','address'])
data1
pd.merge(data,data1,on='customer name')
#sort customers
# Out:
#           customer name   final cost  \
# 0      حمیدرضا تبریزیان  290501028.0
# 1            علی آخوندی  193184177.0
# 2         سید رضا حسینی  147551960.0
# 3         محسن  سلیمانی  108988792.0
# 4       اتوسرویس ترافیک   89339103.0
# 5           پویا هدایتی   80282170.0
# 6      حسین  عبدالرضایی   75885037.0
# 7            عباس بروجی   66337160.0
# 8             محمد بیگی   64855518.0
# 9           فرهاد ثالثی   47780720.0
# 10         عباس حیدریان   19650400.0
# 11            بهفر خانی   18426000.0
# 12     سیدعبدالله  تقوی   14736000.0
# 13        احمد رضا  خرم   13081796.0
# 14                سالار   12436000.0
# 15            عباس ویسی   11780399.0
# 16        محمد رضا گنجی   11240000.0
# 17        حمیدرضا دهقان    8670000.0
# 18          مهران براتي    7860000.0
# 19         محمد شفیعیان    6462000.0
# 20         حمید کهنمویی    3576000.0
# 21  یعقوب صالحی چرمهینی    1720000.0
# 22         حامد  بدیعی      704000.0
#
#                                               address
# ...

# %%
import pandas as pd
import numpy as np
df3=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
#df3.groupby('customer name')['number'].max().sort_values(ascending = False)
dd=pd.DataFrame(df3.groupby('customer name')['number'].max().sort_values(ascending=False))
#dd
pd.DataFrame(df3[df3['id2']==897]['title'])
# Out:
# 0    روغن موتور SL مدل سوپرپيشتاز (20W-50) حجم4لیتر...
# Name: title, dtype: object

# %%
import pandas as pd
data=pd.read_csv('/Users/user/Desktop/Machine Learning/divar_posts_dataset.csv')
data['created_at'].value_counts().sort_values(ascending=False)
data[(data['cat3']=='antiques-and-art') & (data['city']=='Isfahan')]['price'].mean()
data.groupby(['cat1','cat2'])['price'].mean()
phones = data[data['cat3'] == 'mobile-phones']
mean = phones.groupby(['brand'])['price'].mean()

# %%
import pandas as pd
import numpy as np
data3=pd.read_csv('/Users/user/Desktop/Machine Learning/AgentShare-2019-07-17.csv')
data=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
data3.head()
data3['new']=100-data3['percentage']
d3=pd.DataFrame(data3[['id2','new']])
d1=pd.DataFrame(data[['id2','title']])
#display(d3)
result=d3.merge(d1,on='id2')
display(result)
# Out:
#      id2  new                                              title
# 0    895  5.0  روغن موتور SL مدل ریسینگ (10W-40) حجم5لیتر اير...
# 1    893  5.0   روغن موتور SC مدل پلاستیکی (40W) حجم4لیتر سپاهان
# 2    891  5.0                          هزینه ارسال - هزينه ارسال
# 3    890  5.0   روغن موتور SJ مدل پيشتاز (20W-50) حجم1لیتر بهران
# 4    888  5.0  روغن موتور SL مدل ریسینگ (10W-40) حجم4لیتر اير...
# 5    887  5.0           روغن موتور مدل 5000 حجم4لیتر به توتال bt
# 6    886  5.0  روغن موتور SE مدل پلاستیکی (20W-50) حجم4لیتر س...
# 7    885  5.0  روغن موتور SL مدل سوپرپيشتاز (10W-40) حجم4لیتر...
# 8    884  5.0           روغن موتور مدل 7000 حجم4لیتر به توتال bt
# 9    883  5.0  روغن موتور SM MAGNATEC مدل (10W-40) حجم4لیتر ك...
# 10   880  5.0  روغن موتور SM MAGNATEC مدل (10W-40) حجم4لیتر ك...
# 11   879  5.0                          هزینه ارسال - هزينه ارسال
# 12   878  5.0    روغن موتور SG مدل تكتاز (20W-50) حجم4لیتر بهران
# ...

# %%
import pandas as pd
df=pd.read_csv('/Users/user/Desktop/Machine Learning/melb_data.csv')
df.columns

# %%
import pandas as pd
#df=pd.read_csv('/Users/user/Desktop/Machine Learning/melb_data.csv')
file='/Users/user/Desktop/Machine Learning/melb_data.xlsx'
df1=pd.read_excel('/Users/user/Desktop/Machine Learning/melb_data.xlsx')
df = pd.read_excel(file, sep = ',', parse_dates= ['Date'],encoding='utf-8-sig', usecols= ['Date'],)    
df1['Month'] = df['Date'].dt.month
df1
#df1.to_excel('/Users/user/Desktop/Machine Learning/melb_data8.xlsx', engine='xlsxwriter')
#export_csv = df1.to_csv (r'C:\Users\user\Desktop\Machine Learning\melb_data.csv', index = None, header=True)
#print(df1)
# Out:
#        Unnamed: 0             Suburb              Address  Rooms Type  \
# 0               0         Abbotsford         85 Turner St      2    h
# 1               1         Abbotsford      25 Bloomburg St      2    h
# 2               2         Abbotsford         5 Charles St      3    h
# 3               3         Abbotsford     40 Federation La      3    h
# 4               4         Abbotsford          55a Park St      4    h
# 5               5         Abbotsford       129 Charles St      2    h
# 6               6         Abbotsford         124 Yarra St      3    h
# 7               7         Abbotsford        98 Charles St      2    h
# 8               8         Abbotsford   6/241 Nicholson St      1    u
# 9               9         Abbotsford        10 Valiant St      2    h
# 10             10         Abbotsford   411/8 Grosvenor St      2    u
# 11             11         Abbotsford      40 Nicholson St      3    h
# ...

# %%
import pandas as pd
from pandas import DataFrame
dd=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
dd1=pd.read_excel('/Users/user/Desktop/tamrine2.xlsx')
dd1['Date']=dd['Date of Registration'].apply(lambda x:x.split(' ')[0])
dd1.to_excel('/Users/user/Desktop/tamrine4.xlsx', engine='xlsxwriter')

#data = pd.read_csv(file, sep = ',', parse_dates= ['Date'],encoding='utf-8-sig', usecols= ['Date'],)    
#data['Month'] = data['Date'].dt.month
#data

# %%
import pandas as pd
df=pd.read_excel('/Users/user/Desktop/tamrine4.xlsx')
df1=pd.read_excel('/Users/user/Desktop/tamrine4.xlsx')
df1['site_sale_price']=df['final cost']/df['number']
df1.to_excel('/Users/user/Desktop/tamrine5.xlsx', engine='xlsxwriter')

# %%
import pandas as pd
df1=pd.read_excel('/Users/user/Desktop/tamrine4.xlsx')
df2=pd.read_csv('/Users/user/Desktop/Machine Learning/AgentShare-2019-07-17.csv')
d1=pd.DataFrame(df1[['Goods inventory identifier','unit price']])
d2=pd.DataFrame(df2[['Goods inventory identifier','price']])
df1=d1.merge(d2,on='Goods inventory identifier')
df1['rate']=((df1['unit price']-df1['price'])/df1['price'])*100
df1
# Out:
#      Goods inventory identifier  unit price    price        rate
# 0                         372.0      741743   770000   -3.669740
# 1                         372.0      741743   770000   -3.669740
# 2                         372.0      733027   770000   -4.801688
# 3                         372.0      733027   770000   -4.801688
# 4                         372.0      706422   770000   -8.256883
# 5                         372.0      706422   770000   -8.256883
# 6                         372.0      422018   770000  -45.192468
# 7                         490.0      417996   452000   -7.523009
# 8                         490.0      417996   452000   -7.523009
# 9                         490.0      435412   452000   -3.669912
# 10                        490.0      435412   452000   -3.669912
# 11                        490.0      435412   452000   -3.669912
# 12                        490.0      414678   452000   -8.257080
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel('/Users/user/Desktop/tamrine4.xlsx')
month_freq=df['Date'].apply(lambda x:x.split('/')[1]).value_counts()
plt.bar(month_freq.index, month_freq.values)
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel('/Users/user/Desktop/tamrine4.xlsx')
month_freq=df['Date'].apply(lambda x:x.split('/')[1]).value_counts()

# %%
import pandas as pd
import numpy as np
data1=pd.read_csv('/Users/user/Desktop/Machine Learning/AgentShare-2019-07-17.csv')
data2=pd.read_excel('/Users/user/Desktop/tamrine4.xlsx')
d1=pd.DataFrame(data1[['id2','price']])
good_id=data2.apply(lambda x:x.split('-')[1])

d2=pd.DataFrame(data2[['id2','title','unit price']])
res=d1.merge(d2,on='id2')
res['rate']=(data2['unit price']-data1['price'])
res
#result=d2.merge(d1,on='id2')
#display(result)
# Out:
#      id2   price                                              title  \
# 0    895  250200  روغن موتور SL مدل ریسینگ (10W-40) حجم5لیتر اير...
# 1    893  150000   روغن موتور SC مدل پلاستیکی (40W) حجم4لیتر سپاهان
# 2    891  141700                          هزینه ارسال - هزينه ارسال
# 3    890  158400   روغن موتور SJ مدل پيشتاز (20W-50) حجم1لیتر بهران
# 4    888  250200  روغن موتور SL مدل ریسینگ (10W-40) حجم4لیتر اير...
# 5    887  173700           روغن موتور مدل 5000 حجم4لیتر به توتال bt
# 6    886  109800  روغن موتور SE مدل پلاستیکی (20W-50) حجم4لیتر س...
# 7    885   84700  روغن موتور SL مدل سوپرپيشتاز (10W-40) حجم4لیتر...
# 8    884  160000           روغن موتور مدل 7000 حجم4لیتر به توتال bt
# 9    883   86000  روغن موتور SM MAGNATEC مدل (10W-40) حجم4لیتر ك...
# 10   880   94900  روغن موتور SM MAGNATEC مدل (10W-40) حجم4لیتر ك...
# 11   879   93000                          هزینه ارسال - هزينه ارسال
# 12   878  166800    روغن موتور SG مدل تكتاز (20W-50) حجم4لیتر بهران
# ...

# %%
import pandas as pd
data1=pd.read_csv('/Users/user/Desktop/Machine Learning/AgentShare-2019-07-17.csv')
data2=pd.read_excel('/Users/user/Desktop/tamrine5.xlsx')
dd=data1[['Goods inventory identifier','price']]
dd1=data2[['Goods inventory identifier','site_sale_price']]

# %%
dd.merge(dd1,on='Goods inventory identifier')
# Out:
#      Goods inventory identifier    price  site_sale_price
# 0                          2198   257000          2380000
# 1                          2198   257000          2380000
# 2                          2197  1054000          9333000
# 3                          2166   203200           205600
# 4                          2166   203200           205600
# 5                          2166   203200           205600
# 6                          2165  1434000           980000
# 7                          2159   491000            21000
# 8                          2159   491000            21800
# 9                          2158  1380000            24000
# 10                         2158  1380000            24000
# 11                         2158  1380000            25070
# 12                         2157   366000            15000
# 13                         2157   366000            14170
# 14                         2155  1220000            21000
# ...
